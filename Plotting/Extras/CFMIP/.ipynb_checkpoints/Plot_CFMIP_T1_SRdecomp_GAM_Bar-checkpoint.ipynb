# %%
## Import Packages
import numpy as np
import _pickle as pk
import AA as aa
from matplotlib import pyplot as plt
import matplotlib as mpl
from netCDF4 import Dataset
import cartopy.crs as ccrs
from cartopy.util import add_cyclic_point

plt.rcParams['axes.xmargin'] = 0 #default margin spacing for the edges
mpl.rc('font',size=40,**{'family':'sans-serif','sans-serif':['Arial']})
# %matplotlib inline

# %%
Source = '/Users/johnvirgin/OneDrive - University of Waterloo/Papers/GMD_CanESM/'

# %%
#load in cloud feedbacks and dimensions as needed
data_sw = {}
data_lw = {}

mods = ['CanESM2','CanESM5_p2']

for i in range(2):
    data_sw[mods[i]] = pk.load(open(Source+\
        'Data/'+mods[i]+'/CFMIP/Tier 1/'+mods[i]+'_CFMIP_TrCLsw_FB_SRdecomp_Grid.pi','rb'))
    data_lw[mods[i]] = pk.load(open(Source+\
        'Data/'+mods[i]+'/CFMIP/Tier 1/'+mods[i]+'_CFMIP_TrCLlw_FB_SRdecomp_Grid.pi','rb'))

lat = np.linspace(-87.864,87.864,64)
lon = np.linspace(0,357.1875,128)

y = lat*np.pi/180
coslat = np.cos(y)
coslat = np.tile(coslat,(lon.size,1)).T

# %%
data_sw['CanESM2']['Low']['amip-future4K'].shape
# Out:
# (12, 64, 128)

# %%
#take the zonal, annual mean
data_lw_gam = dict()
data_sw_gam = dict()
for mods in data_sw.keys():
    data_sw_gam[mods] = dict()
    data_lw_gam[mods] = dict()
    
    data_sw_gam[mods]['Hi_obs'] = dict()
    data_lw_gam[mods]['Hi_obs'] = dict()
    for prop in data_sw[mods].keys():
        data_sw_gam[mods][prop] = dict()
        data_lw_gam[mods][prop] = dict()
        
        
        for exp in data_sw[mods][prop].keys():
            data_sw_gam[mods][prop][exp] = np.average(np.nanmean(\
            data_sw[mods][prop][exp],axis=0),weights=coslat)
                
            data_lw_gam[mods][prop][exp] = np.average(np.nanmean(\
            data_lw[mods][prop][exp],axis=0),weights=coslat)

# %%
data_sw_gam['CanESM2']
# Out:
# {'Hi_obs': {},
#  'Low': {'amip-future4K': 0.5234583867984386, 'amip-p4K': 0.41152585466800196},
#  'Low_unobscured': {'amip-future4K': 0.3244385496832183,
#   'amip-p4K': 0.27388277320640136},
#  'Hi': {'amip-future4K': -0.7821549175986696, 'amip-p4K': -0.6660942760322449}}

# %%
data_sw_gam['CanESM5_p2']
# Out:
# {'Hi_obs': {},
#  'Low': {'amip-future4K': 0.5950260252583222, 'amip-p4K': 0.4907399802671258},
#  'Low_unobscured': {'amip-future4K': 0.46528950003433267,
#   'amip-p4K': 0.4208013499963187},
#  'Hi': {'amip-future4K': -0.47315172837224806,
#   'amip-p4K': -0.3500232402871165}}

# %%
for mods in data_sw.keys():
    for exp in data_sw_gam[mods]['Low'].keys():
        data_sw_gam[mods]['Hi_obs'][exp] = \
            data_sw_gam[mods]['Low'][exp]-data_sw_gam[mods]['Low_unobscured'][exp]
        data_lw_gam[mods]['Hi_obs'][exp] = \
            data_lw_gam[mods]['Low'][exp]-data_lw_gam[mods]['Low_unobscured'][exp]
print(data_sw_gam['CanESM2'].keys())
# Out:
# dict_keys(['Hi_obs', 'Low', 'Low_unobscured', 'Hi'])

# %%
print(data_sw_gam['CanESM2']['Low_unobscured']['amip-p4K'])
print(data_sw_gam['CanESM5_p2']['Low_unobscured']['amip-p4K'])
# Out:
# 0.27388277320640136
# 0.4208013499963187

# %%
print(data_sw_gam['CanESM2']['Hi_obs']['amip-p4K'])
print(data_sw_gam['CanESM5_p2']['Hi_obs']['amip-p4K'])
# Out:
# 0.1376430814616006
# 0.0699386302708071

# %%
print(data_sw_gam['CanESM2']['Low']['amip-p4K'])
print(data_sw_gam['CanESM5_p2']['Low']['amip-p4K'])
# Out:
# 0.41152585466800196
# 0.4907399802671258

# %%
plt.figure(figsize=(16,16),dpi=300)
plt.subplot(221)
#plt.gca().spines['bottom'].set_position(('data',0))
#plt.gca().spines['top'].set_visible(False)
#plt.gca().spines['right'].set_visible(False)
plt.title('Non-Low Cloud\n\na) amip-p4k',fontsize=20,pad=10)

#CanESM2

#hi
plt.bar(1,data_lw_gam['CanESM2']['Hi']['amip-p4K'],align='edge',width=0.4,color='darkred',\
        alpha=0.4,edgecolor='darkred',label='Non-Low')
plt.text(0.70,data_lw_gam['CanESM2']['Hi']['amip-p4K']/2,\
         str(round(data_lw_gam['CanESM2']['Hi']['amip-p4K'],2)),color='darkred')
plt.bar(1,data_sw_gam['CanESM2']['Hi']['amip-p4K'],align='edge',width=-0.4,color='darkred',\
        alpha=0.4,edgecolor='darkred',label='Non-Low')
plt.text(1.05,data_sw_gam['CanESM2']['Hi']['amip-p4K']/2,\
         str(round(data_sw_gam['CanESM2']['Hi']['amip-p4K'],2)),color='darkred')

#low obscuration
#plt.bar(1,data_lw_gam['CanESM2']['Hi_obs'],align='edge',width=0.4,\
#        bottom=data_lw_gam['CanESM2']['Hi'],\
#        color='darkblue',alpha=0.4,edgecolor='darkblue',label='Obscuration')
#plt.text(0.70,data_lw_gam['CanESM2']['Hi']+(data_lw_gam['CanESM2']['Hi_obs']/2),\
#         str(round(data_lw_gam['CanESM2']['Hi_obs'],2)),color='darkblue')
#plt.bar(1,data_sw_gam['CanESM2']['Hi_obs'],align='edge',width=-0.4,\
#        bottom=data_sw_gam['CanESM2']['Hi'],color='darkblue',alpha=0.4,edgecolor='darkblue')
#plt.text(1.05,data_sw_gam['CanESM2']['Hi']+(data_sw_gam['CanESM2']['Hi_obs']/2),\
#         str(round(data_sw_gam['CanESM2']['Hi_obs'],2)),color='darkblue')


#CanESM5
#hi
plt.bar(3,data_lw_gam['CanESM5_p2']['Hi']['amip-p4K'],align='edge',width=0.4,color='darkred',\
        alpha=0.4,edgecolor='darkred',label='Non-Low')
plt.text(2.70,data_lw_gam['CanESM5_p2']['Hi']['amip-p4K']/2,\
         str(round(data_lw_gam['CanESM5_p2']['Hi']['amip-p4K'],2)),color='darkred')
plt.bar(3,data_sw_gam['CanESM5_p2']['Hi']['amip-p4K'],align='edge',width=-0.4,color='darkred',\
        alpha=0.4,edgecolor='darkred',label='Non-Low')
plt.text(3.05,data_sw_gam['CanESM5_p2']['Hi']['amip-p4K']/2,\
         str(round(data_sw_gam['CanESM5_p2']['Hi']['amip-p4K'],2)),color='darkred')

plt.xlim(0,4)
plt.axhline(0,color='k')
plt.xticks([1,3],labels=['CanESM2','CanESM5'])
plt.ylabel('W m$^{-2}$K$^{-1}$')
plt.ylim(-1.1,1.1);
#plt.legend(loc='lower center')
plt.grid(axis='y')

plt.text(0.725,data_sw_gam['CanESM2']['Hi']['amip-p4K']-0.05,'SW',color='k',fontweight='bold')
plt.text(1.125,data_lw_gam['CanESM2']['Hi']['amip-p4K']+0.025,'LW',color='k',fontweight='bold')

plt.text(2.725,data_sw_gam['CanESM5_p2']['Hi']['amip-p4K']-0.05,'SW',color='k',fontweight='bold')
plt.text(3.125,data_lw_gam['CanESM5_p2']['Hi']['amip-p4K']+0.025,'LW',color='k',fontweight='bold')

#plt.axhline(0,color='k')
#------------
#SHORTWAVE
#------------
plt.subplot(222)
#plt.gca().spines['bottom'].set_position(('data',0))
#plt.gca().spines['top'].set_visible(False)
#plt.gca().spines['right'].set_visible(False)
plt.title('Low Cloud\n\nb) amip-p4k',fontsize=20,pad=10)

#CanESM2

#hi
plt.bar(1,data_lw_gam['CanESM2']['Low_unobscured']['amip-p4K'],align='edge',width=0.4,color='darkblue',\
        alpha=0.4,edgecolor='darkblue')
#plt.text(0.70,data_lw_gam['CanESM2']['Low_unobscured']/2,\
#         str(round(data_lw_gam['CanESM2']['Low_unobscured'],2)),color='darkblue')
plt.bar(1,data_sw_gam['CanESM2']['Low_unobscured']['amip-p4K'],align='edge',width=-0.4,color='darkblue',\
        alpha=0.4,edgecolor='darkblue',label='Low (unobscured)')
plt.text(1.05,data_sw_gam['CanESM2']['Low_unobscured']['amip-p4K']/2,\
         str(round(data_sw_gam['CanESM2']['Low_unobscured']['amip-p4K'],2)),color='darkblue')

#low obscuration
plt.bar(1,data_lw_gam['CanESM2']['Hi_obs']['amip-p4K'],align='edge',width=0.4,\
        bottom=data_lw_gam['CanESM2']['Low_unobscured']['amip-p4K'],\
        color='darkgreen',alpha=0.4,edgecolor='darkgreen',label='Obscuration')
#plt.text(0.70,data_lw_gam['CanESM2']['Low_unobscured']+(data_lw_gam['CanESM2']['Hi_obs']/2),\
#         str(round(data_lw_gam['CanESM2']['Hi_obs'],2)),color='darkgreen')
plt.bar(1,data_sw_gam['CanESM2']['Hi_obs']['amip-p4K'],align='edge',width=-0.4,\
        bottom=data_sw_gam['CanESM2']['Low_unobscured']['amip-p4K'],color='darkgreen',alpha=0.4,edgecolor='darkgreen')
plt.text(1.05,data_sw_gam['CanESM2']['Low_unobscured']['amip-p4K']+(data_sw_gam['CanESM2']['Hi_obs']['amip-p4K']/2),\
         str(round(data_sw_gam['CanESM2']['Hi_obs']['amip-p4K'],2)),color='darkgreen')


#CanESM5
plt.bar(3,data_lw_gam['CanESM5_p2']['Low_unobscured']['amip-p4K'],align='edge',width=0.4,color='darkblue',\
        alpha=0.4,edgecolor='darkblue')
#plt.text(0.70,data_lw_gam['CanESM5_p2']['Low_unobscured']/2,\
#         str(round(data_lw_gam['CanESM5_p2']['Low_unobscured'],2)),color='darkblue')
plt.bar(3,data_sw_gam['CanESM5_p2']['Low_unobscured']['amip-p4K'],align='edge',width=-0.4,color='darkblue',\
        alpha=0.4,edgecolor='darkblue')
plt.text(3.05,data_sw_gam['CanESM5_p2']['Low_unobscured']['amip-p4K']/2,\
         str(round(data_sw_gam['CanESM5_p2']['Low_unobscured']['amip-p4K'],2)),color='darkblue')

#low obscuration
plt.bar(3,data_lw_gam['CanESM5_p2']['Hi_obs']['amip-p4K'],align='edge',width=0.4,\
        bottom=data_lw_gam['CanESM5_p2']['Low_unobscured']['amip-p4K'],\
        color='darkgreen',alpha=0.4,edgecolor='darkgreen')
#plt.text(0.70,data_lw_gam['CanESM5_p2']['Low_unobscured']+(data_lw_gam['CanESM5_p2']['Hi_obs']/2),\
#         str(round(data_lw_gam['CanESM5_p2']['Hi_obs'],2)),color='darkgreen')
plt.bar(3,data_sw_gam['CanESM5_p2']['Hi_obs']['amip-p4K'],align='edge',width=-0.4,\
        bottom=data_sw_gam['CanESM5_p2']['Low_unobscured']['amip-p4K'],color='darkgreen',alpha=0.4,edgecolor='darkgreen')
plt.text(3.05,data_sw_gam['CanESM5_p2']['Low_unobscured']['amip-p4K']+(data_sw_gam['CanESM5_p2']['Hi_obs']['amip-p4K']/2),\
         str(round(data_sw_gam['CanESM5_p2']['Hi_obs']['amip-p4K'],2)),color='darkgreen')

plt.xlim(0,4)
plt.axhline(0,color='k')
plt.xticks([1,3],labels=['CanESM2','CanESM5'])
plt.ylabel('W m$^{-2}$K$^{-1}$')
plt.ylim(-1.1,1.1)
plt.grid(axis='y')
plt.legend()
#plt.axhline(0,color='k')

plt.text(0.725,data_sw_gam['CanESM2']['Low']['amip-p4K']+0.025,'SW',color='k',fontweight='bold')
plt.text(1.125,data_lw_gam['CanESM2']['Low']['amip-p4K']-0.05,'LW',color='k',fontweight='bold')

plt.text(2.725,data_sw_gam['CanESM5_p2']['Low']['amip-p4K']+0.025,'SW',color='k',fontweight='bold')
plt.text(3.125,data_lw_gam['CanESM5_p2']['Low']['amip-p4K']-0.05,'LW',color='k',fontweight='bold');

#NEW PLOTS -------------
plt.subplot(223)
#plt.gca().spines['bottom'].set_position(('data',0))
#plt.gca().spines['top'].set_visible(False)
#plt.gca().spines['right'].set_visible(False)
plt.title('c) amip-future4K',fontsize=20,pad=10)

#CanESM2

#hi
plt.bar(1,data_lw_gam['CanESM2']['Hi']['amip-future4K'],align='edge',width=0.4,color='darkred',\
        alpha=0.4,edgecolor='darkred',label='Non-Low')
plt.text(0.70,data_lw_gam['CanESM2']['Hi']['amip-future4K']/2,\
         str(round(data_lw_gam['CanESM2']['Hi']['amip-future4K'],2)),color='darkred')
plt.bar(1,data_sw_gam['CanESM2']['Hi']['amip-future4K'],align='edge',width=-0.4,color='darkred',\
        alpha=0.4,edgecolor='darkred',label='Non-Low')
plt.text(1.05,data_sw_gam['CanESM2']['Hi']['amip-future4K']/2,\
         str(round(data_sw_gam['CanESM2']['Hi']['amip-future4K'],2)),color='darkred')

#low obscuration
#plt.bar(1,data_lw_gam['CanESM2']['Hi_obs'],align='edge',width=0.4,\
#        bottom=data_lw_gam['CanESM2']['Hi'],\
#        color='darkblue',alpha=0.4,edgecolor='darkblue',label='Obscuration')
#plt.text(0.70,data_lw_gam['CanESM2']['Hi']+(data_lw_gam['CanESM2']['Hi_obs']/2),\
#         str(round(data_lw_gam['CanESM2']['Hi_obs'],2)),color='darkblue')
#plt.bar(1,data_sw_gam['CanESM2']['Hi_obs'],align='edge',width=-0.4,\
#        bottom=data_sw_gam['CanESM2']['Hi'],color='darkblue',alpha=0.4,edgecolor='darkblue')
#plt.text(1.05,data_sw_gam['CanESM2']['Hi']+(data_sw_gam['CanESM2']['Hi_obs']/2),\
#         str(round(data_sw_gam['CanESM2']['Hi_obs'],2)),color='darkblue')


#CanESM5
#hi
plt.bar(3,data_lw_gam['CanESM5_p2']['Hi']['amip-future4K'],align='edge',width=0.4,color='darkred',\
        alpha=0.4,edgecolor='darkred',label='Non-Low')
plt.text(2.70,data_lw_gam['CanESM5_p2']['Hi']['amip-future4K']/2,\
         str(round(data_lw_gam['CanESM5_p2']['Hi']['amip-future4K'],2)),color='darkred')
plt.bar(3,data_sw_gam['CanESM5_p2']['Hi']['amip-future4K'],align='edge',width=-0.4,color='darkred',\
        alpha=0.4,edgecolor='darkred',label='Non-Low')
plt.text(3.05,data_sw_gam['CanESM5_p2']['Hi']['amip-future4K']/2,\
         str(round(data_sw_gam['CanESM5_p2']['Hi']['amip-future4K'],2)),color='darkred')

plt.xlim(0,4)
plt.axhline(0,color='k')
plt.xticks([1,3],labels=['CanESM2','CanESM5'])
plt.ylabel('W m$^{-2}$K$^{-1}$')
plt.ylim(-1.1,1.1);
#plt.legend(loc='lower center')
plt.grid(axis='y')

plt.text(0.725,data_sw_gam['CanESM2']['Hi']['amip-future4K']-0.05,'SW',color='k',fontweight='bold')
plt.text(1.125,data_lw_gam['CanESM2']['Hi']['amip-future4K']+0.025,'LW',color='k',fontweight='bold')

plt.text(2.725,data_sw_gam['CanESM5_p2']['Hi']['amip-future4K']-0.05,'SW',color='k',fontweight='bold')
plt.text(3.125,data_lw_gam['CanESM5_p2']['Hi']['amip-future4K']+0.025,'LW',color='k',fontweight='bold')

#plt.axhline(0,color='k')
#------------
#SHORTWAVE
#------------
plt.subplot(224)
#plt.gca().spines['bottom'].set_position(('data',0))
#plt.gca().spines['top'].set_visible(False)
#plt.gca().spines['right'].set_visible(False)
plt.title('d) amip-future4K',fontsize=20,pad=10)

#CanESM2

#hi
plt.bar(1,data_lw_gam['CanESM2']['Low_unobscured']['amip-future4K'],align='edge',width=0.4,color='darkblue',\
        alpha=0.4,edgecolor='darkblue')
#plt.text(0.70,data_lw_gam['CanESM2']['Low_unobscured']/2,\
#         str(round(data_lw_gam['CanESM2']['Low_unobscured'],2)),color='darkblue')
plt.bar(1,data_sw_gam['CanESM2']['Low_unobscured']['amip-future4K'],align='edge',width=-0.4,color='darkblue',\
        alpha=0.4,edgecolor='darkblue',label='Low (unobscured)')
plt.text(1.05,data_sw_gam['CanESM2']['Low_unobscured']['amip-future4K']/2,\
         str(round(data_sw_gam['CanESM2']['Low_unobscured']['amip-future4K'],2)),color='darkblue')

#low obscuration
plt.bar(1,data_lw_gam['CanESM2']['Hi_obs']['amip-future4K'],align='edge',width=0.4,\
        bottom=data_lw_gam['CanESM2']['Low_unobscured']['amip-future4K'],\
        color='darkgreen',alpha=0.4,edgecolor='darkgreen',label='Obscuration')
#plt.text(0.70,data_lw_gam['CanESM2']['Low_unobscured']+(data_lw_gam['CanESM2']['Hi_obs']/2),\
#         str(round(data_lw_gam['CanESM2']['Hi_obs'],2)),color='darkgreen')
plt.bar(1,data_sw_gam['CanESM2']['Hi_obs']['amip-future4K'],align='edge',width=-0.4,\
        bottom=data_sw_gam['CanESM2']['Low_unobscured']['amip-future4K'],color='darkgreen',alpha=0.4,edgecolor='darkgreen')
plt.text(1.05,data_sw_gam['CanESM2']['Low_unobscured']['amip-future4K']+(data_sw_gam['CanESM2']['Hi_obs']['amip-future4K']/2),\
         str(round(data_sw_gam['CanESM2']['Hi_obs']['amip-future4K'],2)),color='darkgreen')


#CanESM5
plt.bar(3,data_lw_gam['CanESM5_p2']['Low_unobscured']['amip-future4K'],align='edge',width=0.4,color='darkblue',\
        alpha=0.4,edgecolor='darkblue')
#plt.text(0.70,data_lw_gam['CanESM5_p2']['Low_unobscured']/2,\
#         str(round(data_lw_gam['CanESM5_p2']['Low_unobscured'],2)),color='darkblue')
plt.bar(3,data_sw_gam['CanESM5_p2']['Low_unobscured']['amip-future4K'],align='edge',width=-0.4,color='darkblue',\
        alpha=0.4,edgecolor='darkblue')
plt.text(3.05,data_sw_gam['CanESM5_p2']['Low_unobscured']['amip-future4K']/2,\
         str(round(data_sw_gam['CanESM5_p2']['Low_unobscured']['amip-future4K'],2)),color='darkblue')

#low obscuration
plt.bar(3,data_lw_gam['CanESM5_p2']['Hi_obs']['amip-future4K'],align='edge',width=0.4,\
        bottom=data_lw_gam['CanESM5_p2']['Low_unobscured']['amip-future4K'],\
        color='darkgreen',alpha=0.4,edgecolor='darkgreen')
#plt.text(0.70,data_lw_gam['CanESM5_p2']['Low_unobscured']+(data_lw_gam['CanESM5_p2']['Hi_obs']/2),\
#         str(round(data_lw_gam['CanESM5_p2']['Hi_obs'],2)),color='darkgreen')
plt.bar(3,data_sw_gam['CanESM5_p2']['Hi_obs']['amip-future4K'],align='edge',width=-0.4,\
        bottom=data_sw_gam['CanESM5_p2']['Low_unobscured']['amip-future4K'],color='darkgreen',alpha=0.4,edgecolor='darkgreen')
plt.text(3.05,data_sw_gam['CanESM5_p2']['Low_unobscured']['amip-future4K']+(data_sw_gam['CanESM5_p2']['Hi_obs']['amip-future4K']/2),\
         str(round(data_sw_gam['CanESM5_p2']['Hi_obs']['amip-future4K'],2)),color='darkgreen')

plt.xlim(0,4)
plt.axhline(0,color='k')
plt.xticks([1,3],labels=['CanESM2','CanESM5'])
plt.ylabel('W m$^{-2}$K$^{-1}$')
plt.ylim(-1.1,1.1)
plt.grid(axis='y')
#plt.legend()
#plt.axhline(0,color='k')

plt.text(0.725,data_sw_gam['CanESM2']['Low']['amip-future4K']+0.025,'SW',color='k',fontweight='bold')
plt.text(1.125,data_lw_gam['CanESM2']['Low']['amip-future4K']-0.05,'LW',color='k',fontweight='bold')

plt.text(2.725,data_sw_gam['CanESM5_p2']['Low']['amip-future4K']+0.025,'SW',color='k',fontweight='bold')
plt.text(3.125,data_lw_gam['CanESM5_p2']['Low']['amip-future4K']-0.05,'LW',color='k',fontweight='bold');

plt.savefig('CLD_FB_SRDecomp_GAM_Bar_amip.png',bbox_inches='tight')
