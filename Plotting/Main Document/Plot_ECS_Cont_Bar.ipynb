# %%
## Import Packages
import numpy as np
import _pickle as pk
from matplotlib import pyplot as plt
import matplotlib as mpl
import matplotlib.gridspec as gridspec
import os 
import cartopy.crs as ccrs
from cartopy.util import add_cyclic_point

plt.rcParams['axes.xmargin'] = 0 #default margin spacing for the edges
mpl.rc('font',size=40,**{'family':'sans-serif','sans-serif':['Arial']})
# %matplotlib inline

# %%
1.98*0.03
# Out:
# 0.059399999999999994

# %%
plt.figure(figsize=(8,8),dpi=300)
plt.title('Contributions to ECS Difference',fontsize=22,pad=10)

plt.bar(1,-0.08,align='center',width=0.7,color='k',alpha=0.4,edgecolor='k',yerr=0.059/2,capsize=6)
plt.bar(2,0.04,align='center',width=0.7,color='k',alpha=0.4,edgecolor='k',yerr=0.059/2,capsize=6)
plt.bar(3,0.05,align='center',width=0.7,color='k',alpha=0.4,edgecolor='k',yerr=0.059/2,capsize=6)
plt.bar(4,0.34,align='center',width=0.7,color='k',alpha=0.4,edgecolor='k',yerr=0.059/2,capsize=6)
plt.bar(5,0.39,align='center',width=0.7,color='k',alpha=0.4,edgecolor='k',yerr=0.059/2,capsize=6)
plt.bar(6,1.08,align='center',width=0.7,color='k',alpha=0.4,edgecolor='k',yerr=0.059/2,capsize=6)

plt.xlim(0,7.1)
plt.axhline(0,color='k')
plt.xticks([1,2,3,4,5,6],labels=['ERF','Planck','LR+WV','Albedo','CLlw','CLsw'],fontsize=18,rotation=45)
plt.ylabel('K',fontsize=18)
plt.ylim(-0.5,1.2)
plt.yticks(fontsize=18)

plt.grid(axis='y')

plt.savefig('ECS_Cont.png',bbox_inches='tight')
